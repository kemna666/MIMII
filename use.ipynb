# %% [markdown]
# 安装预处理用的包
# 将文件整理成如下形式
# ~~~
# -data
# |
# |- 6db
# |   |- fan
# |   |   |- id_00
# |   |   |   |-normal
# |   |   |   |-abnormal
# |   |   |-id_02
# |   |   |-id_04
# |   |   |-id_06
# |   |- pump
# |   |- slider
# |   |- valve
# |- 0db
# |- -6db
# ~~~

# %%
# %pip install numpy tqdm librosa soundfile

# %% [markdown]
# 数据预处理

# %%
# !python prepare_data.py

# %% [markdown]
# 安装必要包

# %%
# %pip install torch torch_geometric pyyaml scikit-learn matplotlib

# %% [markdown]
# 运行代码

# %%
# !python '/home/kemna/1111/MIMII/main.py'

# %% [markdown]
# 推理

# %%
# !python "/home/kemna/1111/MIMII/predict.py"
# Out:
# 成功加载模型权重: output/best_model.pth
# Traceback (most recent call last):
#   File "/home/kemna/1111/MIMII/predict.py", line 192, in <module>
#     results = predictor.infer_batch(
#         input_path=INPUT_PATH,
#     ...<2 lines>...
#         batch_size=4
#     )
#   File "/home/kemna/1111/MIMII/predict.py", line 130, in infer_batch
#     audio_paths = self._get_audio_files(input_path)
#   File "/home/kemna/1111/MIMII/predict.py", line 98, in _get_audio_files
#     raise ValueError(f"在路径 {input_path} 中未找到任何音频文件")
# ValueError: 在路径 data/test/ 中未找到任何音频文件
